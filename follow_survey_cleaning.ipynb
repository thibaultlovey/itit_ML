# %%
import pandas as pd
import numpy as np
from skimpy import clean_columns
from datetime import datetime

# %%
# Read the CSV file
follow_survey = pd.read_csv("data_raw/follow_survey_raw_12_11_24.csv")
# Clean column names
follow_survey=clean_columns(survey)

# %%
follow_survey.info(verbose=True)

# %%
# remove useless columns
follow_survey = baseline.drop(columns=["identifier", "started"] + list(baseline.loc[:, "location_ts":"context_weather_timezone"].columns))

# %%
survey
# Out:
#     identifier                    id              baseline  \
# 0          NaN                   NaN                   NaN
# 1          NaN                   NaN                   NaN
# 2       survey  NzvMZwEUglhjwduX6tI4  1f3vgd0kJTIpW9yvurtU
# 3       survey  Wvu3gzarBkeSWDhmKkHe  FwXkQasmZjN48tEO3J6K
# 4       survey  VfpMIP1iYUWmrn9vgOPQ  4PI0Rkw6dKBk1PG1fAcm
# ..         ...                   ...                   ...
# 465     survey  0589FM6oQMVxf3dV0s7a  Kf8uuwdg02Y0OsK9a0Fz
# 466     survey  gvloBzEIgecqQB8iuBad  EoBezTlaCFXtcbfcgR2M
# 467     survey  HyY2RNAZ9958sHOOsKeS  IRGieJ6RJjjA5qGpd3JF
# 468     survey  N3Fzb96w3kO4CLO3tcHC  cAArQBE1k6Cij27yaQwh
# 469     survey  BwwIxBbzNVGQIVd3IEbZ  JAWuJ6M9bicJVslyhonF
#
#                           user_id                     started  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2    h9nh0rIXxuRhdlGYofwgWIn5N453  2022-07-30T10:59:55.738804
# 3    lZsYePM7SvbzhNLUUHxLX84eLjJ2  2022-08-26T17:45:05.427908
# 4    K2uAmiD2jHNThUBCMv25ERcka0t1  2022-09-07T17:12:34.591414
# ..                            ...                         ...
# 465  HEAnmAtjAPf9GIAreBADkmAyIr62  2024-11-08T01:50:36.185864
# 466  WqWfFyTW2BMYDteDJHgQ60My4PA2  2024-11-08T17:42:51.245060
# 467  zEyvfC67WYa9gF5cImiHjITjfkL2  2024-11-10T15:59:20.806381
# 468  pg3kS437HFPyMWHZcTMvRopTyuU2  2024-11-11T21:25:05.832592
# 469  zEyvfC67WYa9gF5cImiHjITjfkL2  2024-11-17T15:25:19.548476
#
#                        finished  \
# 0                           NaN
# 1                           NaN
# 2    2022-07-30T11:01:36.683151
# 3    2022-08-26T17:46:27.256662
# 4    2022-09-07T17:15:19.772829
# ..                          ...
# 465  2024-11-08T01:50:56.118888
# 466  2024-11-08T17:44:03.237698
# 467  2024-11-10T15:59:27.812436
# 468  2024-11-11T21:25:19.392435
# 469  2024-11-17T15:25:28.174215
#
#                    survey_symptoms_after_return_skip  \
# 0    Have you experienced any symptoms since return?
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 465                                            false
# 466                                             true
# 467                                            false
# 468                                            false
# 469                                            false
#
#                                     survey_gastro_skip  \
# 0    Did you have any gastrointestinal problems today?
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 465                                                NaN
# 466                                               true
# 467                                                NaN
# 468                                                NaN
# 469                                                NaN
#
#                                 survey_gastro_gastro_0  \
# 0                                               Nausea
# 1    (0=none) (1=mild) (2=moderate) (3=bad) (4=very...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 465                                                NaN
# 466                                                  0
# 467                                                NaN
# 468                                                NaN
# 469                                                NaN
#
#                                 survey_gastro_gastro_1  ...  \
# 0                                             Vomiting  ...
# 1    (0=none) (1=mild) (2=moderate) (3=bad) (4=very...  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 465                                                NaN  ...
# 466                                                  0  ...
# 467                                                NaN  ...
# 468                                                NaN  ...
# 469                                                NaN  ...
#
#     context_weather_currently_wind_bearing  \
# 0                                      NaN
# 1                                      NaN
# 2                                    256.0
# 3                                    310.0
# 4                                     68.0
# ..                                     ...
# 465                                    NaN
# 466                                    NaN
# 467                                    NaN
# 468                                    NaN
# 469                                    NaN
#
#     context_weather_currently_wind_gust context_weather_currently_wind_speed  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                  1.37                                 1.22
# 3                                  2.93                                 2.12
# 4                                  4.14                                 2.19
# ..                                  ...                                  ...
# 465                                 NaN                                  NaN
# 466                                 NaN                                  NaN
# 467                                 NaN                                  NaN
# 468                                 NaN                                  NaN
# 469                                 NaN                                  NaN
#
#     context_weather_latitude context_weather_longitude  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                  47.409564                  8.546910
# 3                  47.696596                  8.632211
# 4                  47.368746                  8.521609
# ..                       ...                       ...
# 465                      NaN                       NaN
# 466                      NaN                       NaN
# 467                      NaN                       NaN
# 468                      NaN                       NaN
# 469                      NaN                       NaN
#
#     context_weather_minutely_data context_weather_minutely_icon  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ..                            ...                           ...
# 465                           NaN                           NaN
# 466                           NaN                           NaN
# 467                           NaN                           NaN
# 468                           NaN                           NaN
# 469                           NaN                           NaN
#
#     context_weather_minutely_summary context_weather_offset  \
# 0                                NaN                    NaN
# 1                                NaN                    NaN
# 2                                NaN                    2.0
# 3                                NaN                    2.0
# 4                                NaN                    2.0
# ..                               ...                    ...
# 465                              NaN                    NaN
# 466                              NaN                    NaN
# 467                              NaN                    NaN
# 468                              NaN                    NaN
# 469                              NaN                    NaN
#
#     context_weather_timezone
# 0                        NaN
# 1                        NaN
# 2              Europe/Zurich
# 3              Europe/Zurich
# 4              Europe/Zurich
# ..                       ...
# 465                      NaN
# 466                      NaN
# 467                      NaN
# 468                      NaN
# 469                      NaN
#
# [470 rows x 169 columns]

# %%
# Read the CSV file
survey = pd.read_csv("data_raw/survey_raw_12_11_24.csv")
# Clean column names
survey=clean_columns(survey)

# remove useless columns
survey = survey.drop(columns=["identifier", "id", "started", "survey_symptoms_skip", "survey_gastro_skip", "survey_resp_skip", "survey_skin_skip", "survey_body_skip", "survey_swelling_skip"] + list(survey.loc[:, "location_ts":"context_air_quality_random_recommendations_sport"].columns))
# remove useless rows
survey = survey.drop([0,1])
